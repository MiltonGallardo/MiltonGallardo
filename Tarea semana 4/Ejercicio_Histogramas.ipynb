# %% [markdown]
# <a href="https://colab.research.google.com/github/MiltonGallardo/MiltonGallardo/blob/main/Tarea%20semana%204/Ejercicio_Histogramas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Ejercicio de Histogramas y diagramas de caja
#
# 1. Traza un histograma del porcentaje de poseedores de perros.
#
# 2. Traza un histograma del porcentaje de poseedores de gatos.
#
# 3a. ¿Qué podemos ver al comparar estos dos histogramas? ¿Qué información nos da?
#
# 3b. Opcional/Extra: traza estos dos histogramas en el mismo plot. A continuación, un ejemplo de cómo debería lucir:
# 4. Crea dos diagramas de caja en el mismo plot: uno con el número medio de gatos por hogar y el otro, del número medio de perros. Más abajo, un ejemplo de cómo podría lucir:
#
# 5. ¿Qué podemos ver al comparar estos dos diagramas de caja? ¿Qué información nos da?

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np

# %%
filename = "/content/drive/MyDrive/ PTCienciaDeDatos/PandasParaManipulaciónDeDatos/catsvdogs.csv"
df = pd.read_csv(filename)
df.head()
# Out:
#      Location Number of Households (in 1000)  ...  Cat Population Unnamed: 12
# 0     Alabama                          1,828  ...           1,252         NaN
# 1     Arizona                          2,515  ...           1,438         NaN
# 2    Arkansas                           1148  ...             810         NaN
# 3  California                         12,974  ...           7,118         NaN
# 4    Colorado                          1,986  ...            1191         NaN
#
# [5 rows x 13 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 13 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   Location                            49 non-null     object
#  1   Number of Households (in 1000)      49 non-null     object
#  2   Percentage of households with pets  49 non-null     float64
#  3   Number of Pet Households (in 1000)  49 non-null     object
#  4   Percentage of Dog Owners            49 non-null     float64
#  5   Dog Owning Households (1000s)       49 non-null     object
#  6   Mean Number of Dogs per household   49 non-null     float64
#  7   Dog Population (in 1000)            49 non-null     object
#  8   Percentage of Cat Owners            49 non-null     float64
#  9   Cat Owning Households               49 non-null     object
#  10  Mean Number of Cats                 49 non-null     float64
# ...

# %%
df['Percentage of Dog Owners'].head()
# Out:
# 0    44.1
# 1    40.1
# 2    47.9
# 3    32.8
# 4    42.5
# Name: Percentage of Dog Owners, dtype: float64

# %%
#1. Traza un histograma del porcentaje de poseedores de perros.
df['Percentage of Dog Owners'].hist()

# %%
df['Percentage of Cat Owners'].head()
# Out:
# 0    27.4
# 1    29.6
# 2    30.6
# 3    28.3
# 4    32.3
# Name: Percentage of Cat Owners, dtype: float64

# %%
# 3. Traza un histograma del porcentaje de poseedores de gatos.
df['Percentage of Cat Owners'].hist()

# %% [markdown]
# 3. Conclusion:
# Existen ciudades con mayor porcentaje de propietarios de perros que otras ciudades
# LOs porcentajes de *propietarios* de perros y gatos en una misma ciudad tienen comportamiento diferente no es proporcional.

# %%
sns.boxplot(data=[df['Mean Number of Dogs per household'],df['Mean Number of Cats']])

# %%
df
# Out:
#                 Location  ... Unnamed: 12
# 0                Alabama  ...         NaN
# 1                Arizona  ...         NaN
# 2               Arkansas  ...         NaN
# 3             California  ...         NaN
# 4               Colorado  ...         NaN
# 5            Connecticut  ...         NaN
# 6               Delaware  ...         NaN
# 7   District of Columbia  ...         NaN
# 8                Florida  ...         NaN
# 9                Georgia  ...         NaN
# 10                 Idaho  ...         NaN
# 11              Illinois  ...         NaN
# 12               Indiana  ...         NaN
# 13                  Iowa  ...         NaN
# 14                Kansas  ...         NaN
# 15              Kentucky  ...         NaN
# 16             Louisiana  ...         NaN
# 17                 Maine  ...         NaN
# 18              Maryland  ...         NaN
# 19         Massachusetts  ...         NaN
# 20              Michigan  ...         NaN
# ...
